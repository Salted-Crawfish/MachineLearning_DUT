# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,f1_score
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
import matplotlib
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,f1_score
from sklearn.metrics import precision_recall_curve, average_precision_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('红酒质量-已清洗.csv')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X = data.drop('quality', axis=1)  
Y = data['quality']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
svc = SVC(probability=True)  
svc.fit(X_train, Y_train)
# Out:
# SVC(probability=True)

# %%
X_train_prediction = svc.predict(X_train)
train_data_accuracy = accuracy_score(X_train_prediction,Y_train)
f1_train =f1_score(X_train_prediction,Y_train,average='weighted')
print(train_data_accuracy)
print(f1_train)
# Out:
# 0.5128617363344051
# 0.5670903659894885

# %%
X_test_prediction = svc.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
f1_test =f1_score(X_test_prediction,Y_test,average='weighted')
print(test_data_accuracy)
print(f1_test)
# Out:
# 0.4919614147909968
# 0.5503136535245587

# %%
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 黑体
matplotlib.rcParams['axes.unicode_minus'] = False  # 解决负号 '-' 显示为方块的问题plt.figure(figsize=(10, 7))

# %%
conf_matrix = confusion_matrix(X_train_prediction,Y_train)
conf_matrix_test = confusion_matrix(X_test_prediction,Y_test)

# 设置图形大小
fig_size = (12, 6)  # 12 英寸宽, 6 英寸高
fig, ax = plt.subplots(1, 2, figsize=fig_size)

# 绘制训练集的混淆矩阵
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[3, 4, 5, 6, 7, 8],  # 根据你的分类标签修改
            yticklabels=[3, 4, 5, 6, 7, 8], ax=ax[0])  # 使用ax[0]指定在哪个子图上绘制
ax[0].set_ylabel('真实值')
ax[0].set_xlabel('预测值')
ax[0].set_title('训练集混淆矩阵')

# 绘制测试集的混淆矩阵
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[3, 4, 5, 6, 7, 8],  # 根据你的分类标签修改
            yticklabels=[3, 4, 5, 6, 7, 8], ax=ax[1])  # 使用ax[1]指定在哪个子图上绘制
ax[1].set_ylabel('真实值')
ax[1].set_xlabel('预测值')
ax[1].set_title('测试集混淆矩阵')

# 自动调整布局
plt.tight_layout()
plt.savefig("svc-数据清洗.png", dpi=300, bbox_inches='tight') 
# 显示图形
plt.show()

# %%
Y_train_probs = svc.predict_proba(X_train)
unique_classes_train = np.unique(Y_train)

# 获取测试集的预测概率
Y_test_probs = svc.predict_proba(X_test)
unique_classes_test = np.unique(Y_test)

# 设置图形大小和子图的排列 (1 行 2 列)
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# 绘制训练集的精度-召回率曲线
for i in unique_classes_train:
    precision, recall, _ = precision_recall_curve(Y_train == i, Y_train_probs[:, i-3])
    ax[0].plot(recall, precision, label=f'等级 {i} (AP = {average_precision_score(Y_train == i, Y_train_probs[:, i-3]):.2f})')

# 绘制测试集的精度-召回率曲线
for i in unique_classes_test:
    precision, recall, _ = precision_recall_curve(Y_test == i, Y_test_probs[:, i-3])
    ax[1].plot(recall, precision, label=f'等级{i} (AP = {average_precision_score(Y_test == i, Y_test_probs[:, i-3]):.2f})')

# 在两个子图中分别绘制随机分类器的对角线
ax[0].plot([0, 1], [1, 0], linestyle='--', color='gray', label='随机分类')
ax[1].plot([0, 1], [1, 0], linestyle='--', color='gray', label='随机分类')

# 设置标题、标签和图例
ax[0].set_title('训练集 精度-召回率曲线')
ax[0].set_xlabel('召回率')
ax[0].set_ylabel('精度')
ax[0].legend(loc='best')

ax[1].set_title('测试集 精度-召回率曲线')
ax[1].set_xlabel('召回率')
ax[1].set_ylabel('精度')
ax[1].legend(loc='best')
plt.savefig("svr-清洗数据-精度召回率-默认.png", dpi=300, bbox_inches='tight') 
# 自动调整布局
plt.tight_layout()

# 显示图形
plt.show()

# %%
df = pd.read_csv('红酒质量-已清洗.csv')

# %%
X = df.drop('quality', axis=1).values
Y = df['quality'].values

# %%
Y = Y - 3

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(6, activation='softmax'))  # 6个类别（3-8）

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 5ms/step - loss: 3.3148 - accuracy: 0.3075 - val_loss: 1.4377 - val_accuracy: 0.3815
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.2437 - accuracy: 0.4744 - val_loss: 1.2913 - val_accuracy: 0.4779
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1821 - accuracy: 0.4754 - val_loss: 1.2412 - val_accuracy: 0.5181
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1775 - accuracy: 0.4774 - val_loss: 1.2387 - val_accuracy: 0.4940
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1363 - accuracy: 0.4925 - val_loss: 1.2328 - val_accuracy: 0.5020
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1308 - accuracy: 0.4864 - val_loss: 1.2244 - val_accuracy: 0.5221
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1620 - accuracy: 0.4824 - val_loss: 1.2589 - val_accuracy: 0.4498
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1288 - accuracy: 0.4894 - val_loss: 1.2463 - val_accuracy: 0.4578
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1930 - accuracy: 0.4774 - val_loss: 1.2365 - val_accuracy: 0.4980
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1308 - accuracy: 0.4834 - val_loss: 1.2205 - val_accuracy: 0.4940
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1036 - accuracy: 0.5035 - val_loss: 1.2067 - val_accuracy: 0.5261
# Epoch 12/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1153 - accuracy: 0.5085 - val_loss: 1.2335 - val_accuracy: 0.4980
# Epoch 13/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1060 - accuracy: 0.5196 - val_loss: 1.2376 - val_accuracy: 0.4980
# Epoch 14/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0985 - accuracy: 0.5226 - val_loss: 1.1914 - val_accuracy: 0.5221
# Epoch 15/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0879 - accuracy: 0.5065 - val_loss: 1.2043 - val_accuracy: 0.4819
# Epoch 16/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0910 - accuracy: 0.5196 - val_loss: 1.1710 - val_accuracy: 0.5582
# Epoch 17/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0770 - accuracy: 0.5417 - val_loss: 1.2495 - val_accuracy: 0.5100
# Epoch 18/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0964 - accuracy: 0.5186 - val_loss: 1.1761 - val_accuracy: 0.5382
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0724 - accuracy: 0.5407 - val_loss: 1.2440 - val_accuracy: 0.4699
# Epoch 20/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1225 - accuracy: 0.4864 - val_loss: 1.1554 - val_accuracy: 0.5462
# Epoch 21/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0872 - accuracy: 0.5387 - val_loss: 1.1490 - val_accuracy: 0.5703
# Epoch 22/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0672 - accuracy: 0.5397 - val_loss: 1.1693 - val_accuracy: 0.5261
# Epoch 23/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1123 - accuracy: 0.5166 - val_loss: 1.2371 - val_accuracy: 0.4940
# Epoch 24/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0819 - accuracy: 0.5467 - val_loss: 1.1498 - val_accuracy: 0.5743
# Epoch 25/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0606 - accuracy: 0.5467 - val_loss: 1.1432 - val_accuracy: 0.5944
# Epoch 26/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0506 - accuracy: 0.5658 - val_loss: 1.3046 - val_accuracy: 0.4378
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0728 - accuracy: 0.5347 - val_loss: 1.2558 - val_accuracy: 0.5060
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1356 - accuracy: 0.5045 - val_loss: 1.1347 - val_accuracy: 0.5863
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0870 - accuracy: 0.5427 - val_loss: 1.1522 - val_accuracy: 0.5382
# Epoch 30/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0634 - accuracy: 0.5487 - val_loss: 1.1456 - val_accuracy: 0.5382
# Epoch 31/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0353 - accuracy: 0.5678 - val_loss: 1.1373 - val_accuracy: 0.5703
# Epoch 32/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0451 - accuracy: 0.5558 - val_loss: 1.1729 - val_accuracy: 0.5141
# Epoch 33/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0792 - accuracy: 0.5266 - val_loss: 1.2677 - val_accuracy: 0.4578
# Epoch 34/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0906 - accuracy: 0.5216 - val_loss: 1.1147 - val_accuracy: 0.5823
# Epoch 35/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0264 - accuracy: 0.5759 - val_loss: 1.1430 - val_accuracy: 0.5582
# Epoch 36/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0488 - accuracy: 0.5588 - val_loss: 1.1232 - val_accuracy: 0.5783
# Epoch 37/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0299 - accuracy: 0.5588 - val_loss: 1.2010 - val_accuracy: 0.4940
# Epoch 38/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1013 - accuracy: 0.5327 - val_loss: 1.2007 - val_accuracy: 0.5261
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0415 - accuracy: 0.5558 - val_loss: 1.1721 - val_accuracy: 0.5060
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0200 - accuracy: 0.5799 - val_loss: 1.1290 - val_accuracy: 0.5703
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0283 - accuracy: 0.5799 - val_loss: 1.0978 - val_accuracy: 0.5944
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0852 - accuracy: 0.5508 - val_loss: 1.2991 - val_accuracy: 0.4297
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0331 - accuracy: 0.5558 - val_loss: 1.1234 - val_accuracy: 0.5703
# Epoch 44/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0234 - accuracy: 0.5528 - val_loss: 1.0946 - val_accuracy: 0.5984
# Epoch 45/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0089 - accuracy: 0.5749 - val_loss: 1.0950 - val_accuracy: 0.5984
# Epoch 46/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0089 - accuracy: 0.5709 - val_loss: 1.1046 - val_accuracy: 0.5904
# Epoch 47/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0004 - accuracy: 0.5879 - val_loss: 1.1035 - val_accuracy: 0.5743
# Epoch 48/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9867 - accuracy: 0.5879 - val_loss: 1.1049 - val_accuracy: 0.5703
# Epoch 49/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0162 - accuracy: 0.5698 - val_loss: 1.1042 - val_accuracy: 0.5542
# Epoch 50/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9942 - accuracy: 0.5779 - val_loss: 1.1777 - val_accuracy: 0.5181
# Epoch 51/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0174 - accuracy: 0.5759 - val_loss: 1.1068 - val_accuracy: 0.5663
# Epoch 52/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0080 - accuracy: 0.5769 - val_loss: 1.1083 - val_accuracy: 0.5622
# Epoch 53/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9991 - accuracy: 0.5940 - val_loss: 1.0830 - val_accuracy: 0.5904
# Epoch 54/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9828 - accuracy: 0.5789 - val_loss: 1.1204 - val_accuracy: 0.5783
# Epoch 55/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9941 - accuracy: 0.5819 - val_loss: 1.1779 - val_accuracy: 0.4940
# Epoch 56/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0151 - accuracy: 0.5678 - val_loss: 1.1537 - val_accuracy: 0.5261
# Epoch 57/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9987 - accuracy: 0.5749 - val_loss: 1.0642 - val_accuracy: 0.5783
# Epoch 58/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9732 - accuracy: 0.5889 - val_loss: 1.0560 - val_accuracy: 0.6064
# Epoch 59/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9662 - accuracy: 0.6101 - val_loss: 1.0909 - val_accuracy: 0.5823
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9738 - accuracy: 0.5990 - val_loss: 1.0458 - val_accuracy: 0.6145
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9871 - accuracy: 0.5759 - val_loss: 1.0686 - val_accuracy: 0.5663
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9681 - accuracy: 0.5889 - val_loss: 1.0964 - val_accuracy: 0.5703
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9748 - accuracy: 0.5839 - val_loss: 1.0587 - val_accuracy: 0.5783
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9797 - accuracy: 0.5910 - val_loss: 1.0473 - val_accuracy: 0.5984
# Epoch 65/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0292 - accuracy: 0.5608 - val_loss: 1.0539 - val_accuracy: 0.5783
# Epoch 66/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9544 - accuracy: 0.5889 - val_loss: 1.0451 - val_accuracy: 0.5823
# Epoch 67/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9603 - accuracy: 0.5910 - val_loss: 1.0467 - val_accuracy: 0.5863
# Epoch 68/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9653 - accuracy: 0.5960 - val_loss: 1.0595 - val_accuracy: 0.5743
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9909 - accuracy: 0.5709 - val_loss: 1.1476 - val_accuracy: 0.5382
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9581 - accuracy: 0.5960 - val_loss: 1.0567 - val_accuracy: 0.5944
# Epoch 71/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9628 - accuracy: 0.5769 - val_loss: 1.0902 - val_accuracy: 0.5863
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9502 - accuracy: 0.6040 - val_loss: 1.0944 - val_accuracy: 0.5663
# Epoch 73/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9629 - accuracy: 0.5899 - val_loss: 1.0446 - val_accuracy: 0.5823
# Epoch 74/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9652 - accuracy: 0.5869 - val_loss: 1.0191 - val_accuracy: 0.6185
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9456 - accuracy: 0.6121 - val_loss: 1.0837 - val_accuracy: 0.5703
# Epoch 76/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9600 - accuracy: 0.6060 - val_loss: 1.0365 - val_accuracy: 0.5863
# Epoch 77/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9479 - accuracy: 0.6040 - val_loss: 1.0197 - val_accuracy: 0.6024
# Epoch 78/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9448 - accuracy: 0.6010 - val_loss: 1.0239 - val_accuracy: 0.6064
# Epoch 79/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9421 - accuracy: 0.5980 - val_loss: 1.0142 - val_accuracy: 0.6185
# Epoch 80/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9347 - accuracy: 0.6070 - val_loss: 1.0151 - val_accuracy: 0.6104
# Epoch 81/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9382 - accuracy: 0.6161 - val_loss: 1.0093 - val_accuracy: 0.6145
# Epoch 82/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9371 - accuracy: 0.6050 - val_loss: 1.0448 - val_accuracy: 0.6024
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9578 - accuracy: 0.5930 - val_loss: 1.0335 - val_accuracy: 0.5944
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9407 - accuracy: 0.6070 - val_loss: 1.0838 - val_accuracy: 0.5703
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9362 - accuracy: 0.6020 - val_loss: 1.0576 - val_accuracy: 0.5783
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9552 - accuracy: 0.5849 - val_loss: 1.0327 - val_accuracy: 0.5823
# Epoch 87/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9592 - accuracy: 0.5869 - val_loss: 0.9970 - val_accuracy: 0.6024
# Epoch 88/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9459 - accuracy: 0.5930 - val_loss: 1.0140 - val_accuracy: 0.6225
# Epoch 89/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9450 - accuracy: 0.5990 - val_loss: 1.0075 - val_accuracy: 0.6024
# Epoch 90/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9386 - accuracy: 0.6070 - val_loss: 1.0888 - val_accuracy: 0.5221
# Epoch 91/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9416 - accuracy: 0.6131 - val_loss: 1.0139 - val_accuracy: 0.5703
# Epoch 92/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9318 - accuracy: 0.6080 - val_loss: 1.0311 - val_accuracy: 0.5743
# Epoch 93/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9505 - accuracy: 0.6080 - val_loss: 1.0308 - val_accuracy: 0.5823
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9168 - accuracy: 0.6171 - val_loss: 1.0920 - val_accuracy: 0.5261
# Epoch 95/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9426 - accuracy: 0.5940 - val_loss: 1.0198 - val_accuracy: 0.6064
# Epoch 96/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9363 - accuracy: 0.5950 - val_loss: 0.9982 - val_accuracy: 0.6064
# Epoch 97/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9054 - accuracy: 0.6141 - val_loss: 1.0346 - val_accuracy: 0.5823
# Epoch 98/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9265 - accuracy: 0.6050 - val_loss: 0.9958 - val_accuracy: 0.6104
# Epoch 99/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9182 - accuracy: 0.6201 - val_loss: 0.9942 - val_accuracy: 0.5783
# Epoch 100/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9268 - accuracy: 0.6181 - val_loss: 1.0758 - val_accuracy: 0.5823

# %%
Y_train_pred = model.predict(X_train)
Y_train_pred_max = np.argmax(Y_train_pred, axis=1)
accuracy = accuracy_score(Y_train_pred_max, Y_train)
print(f"Accuracy: {accuracy:.4f}")
f1_train= f1_score(Y_train_pred_max, Y_train, average='weighted')
print(f1_train)
# Out:
# 39/39 [==============================] - 0s 579us/step
# Accuracy: 0.5675
# 0.6106756239770065

# %%
Y_test_pred = model.predict(X_test)
Y_test_pred_max = np.argmax(Y_test_pred, axis=1)
accuracy = accuracy_score(Y_test_pred_max, Y_test)
print(f"Accuracy: {accuracy:.4f}")
f1_test= f1_score(Y_test_pred_max, Y_test, average='weighted')
print(f1_test)
# Out:
# 10/10 [==============================] - 0s 778us/step
# Accuracy: 0.5016
# 0.5406835063695457

# %%
conf_matrix = confusion_matrix(Y_train_pred_max, Y_train)
conf_matrix_test = confusion_matrix(Y_test_pred_max, Y_test)

# 设置图形大小
fig_size = (12, 6)  # 12 英寸宽, 6 英寸高
fig, ax = plt.subplots(1, 2, figsize=fig_size)

# 绘制训练集的混淆矩阵
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[3, 4, 5, 6, 7, 8],  # 根据你的分类标签修改
            yticklabels=[3, 4, 5, 6, 7, 8], ax=ax[0])  # 使用ax[0]指定在哪个子图上绘制
ax[0].set_ylabel('真实值')
ax[0].set_xlabel('预测值')
ax[0].set_title('训练集混淆矩阵')

# 绘制测试集的混淆矩阵
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[3, 4, 5, 6, 7, 8],  # 根据你的分类标签修改
            yticklabels=[3, 4, 5, 6, 7, 8], ax=ax[1])  # 使用ax[1]指定在哪个子图上绘制
ax[1].set_ylabel('真实值')
ax[1].set_xlabel('预测值')
ax[1].set_title('测试集混淆矩阵')

# 自动调整布局
plt.tight_layout()
plt.savefig("NN-数据清洗.png", dpi=300, bbox_inches='tight') 
# 显示图形
plt.show()

# %%
Y_train_probs = model.predict(X_train)
Y_test_probs = model.predict(X_test)

# 获取唯一类别标签
unique_classes_train = np.unique(Y_train)
unique_classes_test = np.unique(Y_test)

# 设置图形大小和子图的排列 (1 行 2 列)
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# 绘制训练集的精度-召回率曲线
for i in unique_classes_train:
    precision, recall, _ = precision_recall_curve(Y_train == i, Y_train_probs[:, i])
    average_precision = average_precision_score(Y_train == i, Y_train_probs[:, i])
    ax[0].plot(recall, precision, label=f'等级 {i+3} (AP = {average_precision:.2f})')

# 绘制测试集的精度-召回率曲线
for i in unique_classes_test:
    precision, recall, _ = precision_recall_curve(Y_test == i, Y_test_probs[:, i])
    average_precision = average_precision_score(Y_test == i, Y_test_probs[:, i])
    ax[1].plot(recall, precision, label=f'等级 {i+3} (AP = {average_precision:.2f})')

# 在两个子图中分别绘制随机分类器的对角线
ax[0].plot([0, 1], [1, 0], linestyle='--', color='gray', label='随机分类')
ax[1].plot([0, 1], [1, 0], linestyle='--', color='gray', label='随机分类')

# 设置标题、标签和图例
ax[0].set_title('训练集 精度-召回率曲线')
ax[0].set_xlabel('召回率')
ax[0].set_ylabel('精度')
ax[0].legend(loc='best')

ax[1].set_title('测试集 精度-召回率曲线')
ax[1].set_xlabel('召回率')
ax[1].set_ylabel('精度')
ax[1].legend(loc='best')

# 保存并显示图形
plt.tight_layout()
plt.savefig("nn-清洗数据-精度召回率-默认.png", dpi=300, bbox_inches='tight') 
plt.show()
# Out:
# 39/39 [==============================] - 0s 632us/step
# 10/10 [==============================] - 0s 778us/step
