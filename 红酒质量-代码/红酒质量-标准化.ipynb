# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,f1_score
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
import matplotlib
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,f1_score
from sklearn.metrics import precision_recall_curve, average_precision_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('红酒质量-已清洗.csv')
X = data.drop('quality', axis=1)  
Y = data['quality']  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
svc = SVC(probability=True)  
svc.fit(X_train_scaled, Y_train)
# Out:
# SVC(probability=True)

# %%
X_train_prediction = svc.predict(X_train_scaled)
train_data_accuracy = accuracy_score(X_train_prediction,Y_train)
f1_train =f1_score(X_train_prediction,Y_train,average='weighted')
print(train_data_accuracy)
print(f1_train)
# Out:
# 0.6752411575562701
# 0.7030631169567833

# %%
X_test_prediction = svc.predict(X_test_scaled)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
f1_test =f1_score(X_test_prediction,Y_test,average='weighted')
print(test_data_accuracy)
print(f1_test)
# Out:
# 0.6109324758842444
# 0.6282468253706632

# %%
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 黑体
matplotlib.rcParams['axes.unicode_minus'] = False  # 解决负号 '-' 显示为方块的问题plt.figure(figsize=(10, 7))

# %%
conf_matrix = confusion_matrix(X_train_prediction,Y_train)
conf_matrix_test = confusion_matrix(X_test_prediction,Y_test)

# 设置图形大小
fig_size = (12, 6)  # 12 英寸宽, 6 英寸高
fig, ax = plt.subplots(1, 2, figsize=fig_size)

# 绘制训练集的混淆矩阵
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[3, 4, 5, 6, 7, 8],  # 根据你的分类标签修改
            yticklabels=[3, 4, 5, 6, 7, 8], ax=ax[0])  # 使用ax[0]指定在哪个子图上绘制
ax[0].set_ylabel('真实值')
ax[0].set_xlabel('预测值')
ax[0].set_title('训练集混淆矩阵')

# 绘制测试集的混淆矩阵
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[3, 4, 5, 6, 7, 8],  # 根据你的分类标签修改
            yticklabels=[3, 4, 5, 6, 7, 8], ax=ax[1])  # 使用ax[1]指定在哪个子图上绘制
ax[1].set_ylabel('真实值')
ax[1].set_xlabel('预测值')
ax[1].set_title('测试集混淆矩阵')

# 自动调整布局
plt.tight_layout()
plt.savefig("svc-标准化.png", dpi=300, bbox_inches='tight') 
# 显示图形
plt.show()

# %%
Y_train_probs = svc.predict_proba(X_train)
unique_classes_train = np.unique(Y_train)

# 获取测试集的预测概率
Y_test_probs = svc.predict_proba(X_test)
unique_classes_test = np.unique(Y_test)

# 设置图形大小和子图的排列 (1 行 2 列)
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# 绘制训练集的精度-召回率曲线
for i in unique_classes_train:
    precision, recall, _ = precision_recall_curve(Y_train == i, Y_train_probs[:, i-3])
    ax[0].plot(recall, precision, label=f'等级 {i} (AP = {average_precision_score(Y_train == i, Y_train_probs[:, i-3]):.2f})')

# 绘制测试集的精度-召回率曲线
for i in unique_classes_test:
    precision, recall, _ = precision_recall_curve(Y_test == i, Y_test_probs[:, i-3])
    ax[1].plot(recall, precision, label=f'等级{i} (AP = {average_precision_score(Y_test == i, Y_test_probs[:, i-3]):.2f})')

# 在两个子图中分别绘制随机分类器的对角线
ax[0].plot([0, 1], [1, 0], linestyle='--', color='gray', label='随机分类')
ax[1].plot([0, 1], [1, 0], linestyle='--', color='gray', label='随机分类')

# 设置标题、标签和图例
ax[0].set_title('训练集 精度-召回率曲线')
ax[0].set_xlabel('召回率')
ax[0].set_ylabel('精度')
ax[0].legend(loc='best')

ax[1].set_title('测试集 精度-召回率曲线')
ax[1].set_xlabel('召回率')
ax[1].set_ylabel('精度')
ax[1].legend(loc='best')
plt.savefig("svr-标准化-精度召回率-默认.png", dpi=300, bbox_inches='tight') 
# 自动调整布局
plt.tight_layout()

# 显示图形
plt.show()

# %%
df = pd.read_csv('红酒质量-已清洗.csv')
X = df.drop('quality', axis=1)
Y = df['quality']
Y = Y - 3
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(6, activation='softmax'))  # 6个类别（3-8）

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 5ms/step - loss: 4.6738 - accuracy: 0.2874 - val_loss: 1.5327 - val_accuracy: 0.4056
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.3382 - accuracy: 0.4714 - val_loss: 1.3593 - val_accuracy: 0.5020
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.2099 - accuracy: 0.4935 - val_loss: 1.2651 - val_accuracy: 0.4659
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1436 - accuracy: 0.4894 - val_loss: 1.2094 - val_accuracy: 0.5221
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1328 - accuracy: 0.4864 - val_loss: 1.1953 - val_accuracy: 0.5382
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1188 - accuracy: 0.4945 - val_loss: 1.2116 - val_accuracy: 0.5020
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1157 - accuracy: 0.5065 - val_loss: 1.1835 - val_accuracy: 0.5462
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1190 - accuracy: 0.5126 - val_loss: 1.2123 - val_accuracy: 0.5221
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1107 - accuracy: 0.5015 - val_loss: 1.1903 - val_accuracy: 0.5261
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1037 - accuracy: 0.5136 - val_loss: 1.2112 - val_accuracy: 0.5261
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1122 - accuracy: 0.4985 - val_loss: 1.2029 - val_accuracy: 0.5341
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1030 - accuracy: 0.5116 - val_loss: 1.1814 - val_accuracy: 0.5301
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1222 - accuracy: 0.4955 - val_loss: 1.1767 - val_accuracy: 0.5542
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0982 - accuracy: 0.5246 - val_loss: 1.2057 - val_accuracy: 0.4699
# Epoch 15/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1036 - accuracy: 0.5166 - val_loss: 1.1758 - val_accuracy: 0.5582
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0882 - accuracy: 0.5276 - val_loss: 1.1664 - val_accuracy: 0.5261
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0854 - accuracy: 0.5116 - val_loss: 1.2145 - val_accuracy: 0.5221
# Epoch 18/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1183 - accuracy: 0.5206 - val_loss: 1.2267 - val_accuracy: 0.4980
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0861 - accuracy: 0.5216 - val_loss: 1.1804 - val_accuracy: 0.5301
# Epoch 20/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0870 - accuracy: 0.5136 - val_loss: 1.1839 - val_accuracy: 0.4699
# Epoch 21/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0865 - accuracy: 0.5186 - val_loss: 1.1459 - val_accuracy: 0.5743
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0737 - accuracy: 0.5146 - val_loss: 1.1700 - val_accuracy: 0.5261
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0657 - accuracy: 0.5317 - val_loss: 1.1915 - val_accuracy: 0.4699
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0943 - accuracy: 0.5357 - val_loss: 1.1670 - val_accuracy: 0.5462
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0819 - accuracy: 0.5437 - val_loss: 1.1361 - val_accuracy: 0.5663
# Epoch 26/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0628 - accuracy: 0.5487 - val_loss: 1.1476 - val_accuracy: 0.5743
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0634 - accuracy: 0.5578 - val_loss: 1.1572 - val_accuracy: 0.5502
# Epoch 28/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0628 - accuracy: 0.5256 - val_loss: 1.1625 - val_accuracy: 0.5743
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1526 - accuracy: 0.5266 - val_loss: 1.1601 - val_accuracy: 0.5622
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0801 - accuracy: 0.5136 - val_loss: 1.1331 - val_accuracy: 0.5944
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0527 - accuracy: 0.5487 - val_loss: 1.1123 - val_accuracy: 0.5904
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0516 - accuracy: 0.5457 - val_loss: 1.1537 - val_accuracy: 0.5663
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0508 - accuracy: 0.5668 - val_loss: 1.1165 - val_accuracy: 0.5743
# Epoch 34/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0621 - accuracy: 0.5317 - val_loss: 1.1150 - val_accuracy: 0.5743
# Epoch 35/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0404 - accuracy: 0.5457 - val_loss: 1.1744 - val_accuracy: 0.4940
# Epoch 36/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0782 - accuracy: 0.5327 - val_loss: 1.1145 - val_accuracy: 0.5743
# Epoch 37/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0465 - accuracy: 0.5598 - val_loss: 1.1851 - val_accuracy: 0.4900
# Epoch 38/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0467 - accuracy: 0.5608 - val_loss: 1.1368 - val_accuracy: 0.5502
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0234 - accuracy: 0.5568 - val_loss: 1.1206 - val_accuracy: 0.5622
# Epoch 40/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0374 - accuracy: 0.5658 - val_loss: 1.1242 - val_accuracy: 0.5743
# Epoch 41/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0161 - accuracy: 0.5678 - val_loss: 1.1410 - val_accuracy: 0.5341
# Epoch 42/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0217 - accuracy: 0.5779 - val_loss: 1.1089 - val_accuracy: 0.5542
# Epoch 43/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0624 - accuracy: 0.5116 - val_loss: 1.2166 - val_accuracy: 0.4699
# Epoch 44/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0431 - accuracy: 0.5427 - val_loss: 1.1059 - val_accuracy: 0.5743
# Epoch 45/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0514 - accuracy: 0.5638 - val_loss: 1.1330 - val_accuracy: 0.5622
# Epoch 46/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0202 - accuracy: 0.5678 - val_loss: 1.1309 - val_accuracy: 0.5622
# Epoch 47/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0148 - accuracy: 0.5648 - val_loss: 1.1164 - val_accuracy: 0.5261
# Epoch 48/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0082 - accuracy: 0.5889 - val_loss: 1.1078 - val_accuracy: 0.5823
# Epoch 49/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0040 - accuracy: 0.5789 - val_loss: 1.1179 - val_accuracy: 0.5663
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0317 - accuracy: 0.5477 - val_loss: 1.1363 - val_accuracy: 0.5462
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0073 - accuracy: 0.5678 - val_loss: 1.1923 - val_accuracy: 0.4900
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0201 - accuracy: 0.5457 - val_loss: 1.1278 - val_accuracy: 0.5100
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0060 - accuracy: 0.5809 - val_loss: 1.1229 - val_accuracy: 0.5462
# Epoch 54/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0054 - accuracy: 0.5749 - val_loss: 1.1135 - val_accuracy: 0.5622
# Epoch 55/100
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0140 - accuracy: 0.5709 - val_loss: 1.1968 - val_accuracy: 0.4940
# Epoch 56/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0341 - accuracy: 0.5437 - val_loss: 1.0657 - val_accuracy: 0.5904
# Epoch 57/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0183 - accuracy: 0.5588 - val_loss: 1.0927 - val_accuracy: 0.5984
# Epoch 58/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9876 - accuracy: 0.5799 - val_loss: 1.1091 - val_accuracy: 0.5823
# Epoch 59/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0090 - accuracy: 0.5719 - val_loss: 1.0566 - val_accuracy: 0.5944
# Epoch 60/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9836 - accuracy: 0.5809 - val_loss: 1.1137 - val_accuracy: 0.5502
# Epoch 61/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0153 - accuracy: 0.5568 - val_loss: 1.1373 - val_accuracy: 0.5141
# Epoch 62/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9784 - accuracy: 0.5799 - val_loss: 1.1329 - val_accuracy: 0.5502
# Epoch 63/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9855 - accuracy: 0.5809 - val_loss: 1.1038 - val_accuracy: 0.5462
# Epoch 64/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9835 - accuracy: 0.5829 - val_loss: 1.1279 - val_accuracy: 0.5422
# Epoch 65/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9887 - accuracy: 0.5759 - val_loss: 1.1397 - val_accuracy: 0.5221
# Epoch 66/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9983 - accuracy: 0.5970 - val_loss: 1.1235 - val_accuracy: 0.5462
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9769 - accuracy: 0.5889 - val_loss: 1.0601 - val_accuracy: 0.5823
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9736 - accuracy: 0.5789 - val_loss: 1.0764 - val_accuracy: 0.5743
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9788 - accuracy: 0.5779 - val_loss: 1.1209 - val_accuracy: 0.5502
# Epoch 70/100
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0096 - accuracy: 0.5618 - val_loss: 1.0589 - val_accuracy: 0.5703
# Epoch 71/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9818 - accuracy: 0.5829 - val_loss: 1.0739 - val_accuracy: 0.5783
# Epoch 72/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9914 - accuracy: 0.5809 - val_loss: 1.0782 - val_accuracy: 0.5703
# Epoch 73/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9732 - accuracy: 0.6030 - val_loss: 1.0718 - val_accuracy: 0.6064
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9769 - accuracy: 0.5889 - val_loss: 1.0705 - val_accuracy: 0.5703
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9605 - accuracy: 0.5859 - val_loss: 1.0657 - val_accuracy: 0.5783
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9972 - accuracy: 0.5809 - val_loss: 1.0770 - val_accuracy: 0.5944
# Epoch 77/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9522 - accuracy: 0.5859 - val_loss: 1.0826 - val_accuracy: 0.5582
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9689 - accuracy: 0.5960 - val_loss: 1.1293 - val_accuracy: 0.5301
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9975 - accuracy: 0.5668 - val_loss: 1.0492 - val_accuracy: 0.5944
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9609 - accuracy: 0.5879 - val_loss: 1.0477 - val_accuracy: 0.5783
# Epoch 81/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9480 - accuracy: 0.6000 - val_loss: 1.0374 - val_accuracy: 0.5904
# Epoch 82/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9634 - accuracy: 0.5980 - val_loss: 1.0543 - val_accuracy: 0.5582
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9586 - accuracy: 0.5950 - val_loss: 1.0549 - val_accuracy: 0.6064
# Epoch 84/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9773 - accuracy: 0.5789 - val_loss: 1.0750 - val_accuracy: 0.5904
# Epoch 85/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9680 - accuracy: 0.5839 - val_loss: 1.0915 - val_accuracy: 0.5422
# Epoch 86/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9538 - accuracy: 0.5879 - val_loss: 1.0664 - val_accuracy: 0.5783
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9685 - accuracy: 0.5789 - val_loss: 1.0728 - val_accuracy: 0.5462
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9405 - accuracy: 0.6010 - val_loss: 1.0363 - val_accuracy: 0.5663
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9420 - accuracy: 0.6060 - val_loss: 1.0440 - val_accuracy: 0.6145
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9644 - accuracy: 0.5789 - val_loss: 1.0574 - val_accuracy: 0.5904
# Epoch 91/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9449 - accuracy: 0.5859 - val_loss: 1.0289 - val_accuracy: 0.5863
# Epoch 92/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9575 - accuracy: 0.5678 - val_loss: 1.0130 - val_accuracy: 0.6064
# Epoch 93/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9285 - accuracy: 0.6131 - val_loss: 1.0483 - val_accuracy: 0.5904
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9394 - accuracy: 0.6040 - val_loss: 1.0325 - val_accuracy: 0.6024
# Epoch 95/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9530 - accuracy: 0.5910 - val_loss: 1.0631 - val_accuracy: 0.5462
# Epoch 96/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9523 - accuracy: 0.5759 - val_loss: 1.0389 - val_accuracy: 0.5783
# Epoch 97/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9446 - accuracy: 0.6010 - val_loss: 1.0242 - val_accuracy: 0.5783
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9231 - accuracy: 0.6040 - val_loss: 1.0158 - val_accuracy: 0.5863
# Epoch 99/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9187 - accuracy: 0.6121 - val_loss: 1.0268 - val_accuracy: 0.5703
# Epoch 100/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9272 - accuracy: 0.6111 - val_loss: 1.0163 - val_accuracy: 0.6024

# %%
Y_train_pred = model.predict(X_train)
Y_train_pred_max = np.argmax(Y_train_pred, axis=1)
accuracy = accuracy_score(Y_train_pred_max, Y_train)
print(f"Accuracy: {accuracy:.4f}")
f1_train= f1_score(Y_train_pred_max, Y_train, average='weighted')
print(f1_train)
# Out:
# 39/39 [==============================] - 0s 763us/step
# Accuracy: 0.6093
# 0.6292614531898328

# %%
Y_test_pred = model.predict(X_test)
Y_test_pred_max = np.argmax(Y_test_pred, axis=1)
accuracy = accuracy_score(Y_test_pred_max, Y_test)
print(f"Accuracy: {accuracy:.4f}")
f1_test= f1_score(Y_test_pred_max, Y_test, average='weighted')
print(f1_test)
# Out:
# 10/10 [==============================] - 0s 889us/step
# Accuracy: 0.5466
# 0.5570903674321918

# %%
conf_matrix = confusion_matrix(Y_train_pred_max, Y_train)
conf_matrix_test = confusion_matrix(Y_test_pred_max, Y_test)

# 设置图形大小
fig_size = (12, 6)  # 12 英寸宽, 6 英寸高
fig, ax = plt.subplots(1, 2, figsize=fig_size)

# 绘制训练集的混淆矩阵
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[3, 4, 5, 6, 7, 8],  # 根据你的分类标签修改
            yticklabels=[3, 4, 5, 6, 7, 8], ax=ax[0])  # 使用ax[0]指定在哪个子图上绘制
ax[0].set_ylabel('真实值')
ax[0].set_xlabel('预测值')
ax[0].set_title('训练集混淆矩阵')

# 绘制测试集的混淆矩阵
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[3, 4, 5, 6, 7, 8],  # 根据你的分类标签修改
            yticklabels=[3, 4, 5, 6, 7, 8], ax=ax[1])  # 使用ax[1]指定在哪个子图上绘制
ax[1].set_ylabel('真实值')
ax[1].set_xlabel('预测值')
ax[1].set_title('测试集混淆矩阵')

# 自动调整布局
plt.tight_layout()
plt.savefig("NN-标准化.png", dpi=300, bbox_inches='tight') 
# 显示图形
plt.show()

# %%
Y_train_probs = model.predict(X_train)
Y_test_probs = model.predict(X_test)

# 获取唯一类别标签
unique_classes_train = np.unique(Y_train)
unique_classes_test = np.unique(Y_test)

# 设置图形大小和子图的排列 (1 行 2 列)
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# 绘制训练集的精度-召回率曲线
for i in unique_classes_train:
    precision, recall, _ = precision_recall_curve(Y_train == i, Y_train_probs[:, i])
    average_precision = average_precision_score(Y_train == i, Y_train_probs[:, i])
    ax[0].plot(recall, precision, label=f'等级 {i+3} (AP = {average_precision:.2f})')

# 绘制测试集的精度-召回率曲线
for i in unique_classes_test:
    precision, recall, _ = precision_recall_curve(Y_test == i, Y_test_probs[:, i])
    average_precision = average_precision_score(Y_test == i, Y_test_probs[:, i])
    ax[1].plot(recall, precision, label=f'等级 {i+3} (AP = {average_precision:.2f})')

# 在两个子图中分别绘制随机分类器的对角线
ax[0].plot([0, 1], [1, 0], linestyle='--', color='gray', label='随机分类')
ax[1].plot([0, 1], [1, 0], linestyle='--', color='gray', label='随机分类')

# 设置标题、标签和图例
ax[0].set_title('训练集 精度-召回率曲线')
ax[0].set_xlabel('召回率')
ax[0].set_ylabel('精度')
ax[0].legend(loc='best')

ax[1].set_title('测试集 精度-召回率曲线')
ax[1].set_xlabel('召回率')
ax[1].set_ylabel('精度')
ax[1].legend(loc='best')

# 保存并显示图形
plt.tight_layout()
plt.savefig("nn-标准化-精度召回率-默认.png", dpi=300, bbox_inches='tight') 
plt.show()
# Out:
# 39/39 [==============================] - 0s 632us/step
# 10/10 [==============================] - 0s 778us/step
